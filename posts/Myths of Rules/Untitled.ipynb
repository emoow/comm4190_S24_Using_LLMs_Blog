# %%
---
title: "Myths of rules generated by LLMs"
description: "Can I generate a rock n roll using LLMs?"
author: "Emoo"
date: "4/23/2024"
categories:
  - LLMs
  - myths of rules
  - prompt
  - literature
---
